# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import scipy.stats as stats

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression

from sklearn.metrics import r2_score

from sklearn.preprocessing import PowerTransformer

# %%
df = pd.read_csv('concrete_data.csv')

# %%
df
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
X = df.drop(columns=['Strength'])
y = df.iloc[:,1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state=0)

# %%
#Applying linear regression without any transform

lr = LinearRegression()
lr.fit(X_train,y_train)

y_pred = lr.predict(X_test)

r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
# cross checking with cross val score

lr = LinearRegression()
np.mean(cross_val_score(lr,X,y,scoring='r2'))
# Out:
# np.float64(1.0)

# %%
#plotting the displots without any transformation

for col in X_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)

    plt.subplot(122)
    stats.probplot(X_train[col],dist="norm",plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\PRABHAV\AppData\Local\Temp\ipykernel_21016\367677658.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# C:\Users\PRABHAV\AppData\Local\Temp\ipykernel_21016\367677658.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# ...

# %%
#applying box_cox tramsformation

pt = PowerTransformer(method='box-cox')

X_train_transformed = pt.fit_transform(X_train+0.0000001)
X_test_transformed = pt.transform(X_test+0.000000001)

pd.DataFrame({'cols':X_train.columns,'box_cox_lambdas':pt.lambdas_})
# Out:
#                  cols  box_cox_lambdas
# 0              Cement         0.153049
# 1  Blast Furnace Slag         0.028307
# 2             Fly Ash        -0.030326
# 3               Water         0.888072
# 4    Superplasticizer         0.096020
# 5    Coarse Aggregate         1.115681
# 6      Fine Aggregate         1.789591
# 7                 Age         0.063010

# %%
#applying LR on tramsformed data
lr = LinearRegression()
lr.fit(X_train_transformed,y_train)

y_pred = lr.predict(X_test_transformed)

r2_score(y_test,y_pred)
# Out:
# 0.6940846289943303

# %%
# cross checking with cross val score
pt = PowerTransformer(method='box-cox')
X_transformed = pt.fit_transform(X+0.0000001)

lr =LinearRegression()
np.mean(cross_val_score(lr,X_transformed,y,scoring='r2'))
# Out:
# np.float64(0.6320035776062856)

# %%
#before and after comaprison for box cox plot

for i, col in enumerate(X_train.columns):

    plt.figure(figsize=(14,4))

    plt.subplot(121)
    sns.histplot(X_train[col], kde=True)
    plt.title(f'Before: {col}')

    plt.subplot(122)
    sns.histplot(X_train_transformed[:, i],kde=True)
    plt.title(f'After: {col}')

    plt.tight_layout()
    plt.show()

# %%
#applying box_cox tramsformation

pt1 = PowerTransformer()

X_train_transformed2 = pt1.fit_transform(X_train)
X_test_transformed2 = pt1.transform(X_test)

lr = LinearRegression()
lr.fit(X_train_transformed2,y_train)

y_pred3 = lr.predict(X_test_transformed2)

print(r2_score(y_test,y_pred3))

pd.DataFrame({'cols':X_train.columns,'yeo_johnson_lambdas':pt1.lambdas_})
# Out:
# 0.8753591355935926
#                  cols  yeo_johnson_lambdas
# 0              Cement             0.150260
# 1  Blast Furnace Slag             0.038667
# 2             Fly Ash            -0.141876
# 3               Water             0.887369
# 4    Superplasticizer             0.293603
# 5    Coarse Aggregate             1.115901
# 6      Fine Aggregate             1.790678
# 7                 Age             0.016397

# %%
# cross checking with cross val score
pt = PowerTransformer()
X_transformed2 = pt.fit_transform(X)

lr =LinearRegression()
np.mean(cross_val_score(lr,X_transformed2,y,scoring='r2'))
# Out:
# np.float64(0.7568908875555878)

# %%
#before and after comparison for yeo johnson

for i, col in enumerate(X_train.columns):

    plt.figure(figsize=(14,4))

    plt.subplot(121)
    sns.histplot(X_train[col], kde=True)
    plt.title(f'Before: {col}')

    plt.subplot(122)
    sns.histplot(X_train_transformed2[:, i],kde=True)
    plt.title(f'After: {col}')

    plt.tight_layout()
    plt.show()

# %%
# comparison of lambda values of box cox and yeo johnson
pd.DatFrame({'cols':X_train.columns,'box_cox_lambdas':pt_lambd})
