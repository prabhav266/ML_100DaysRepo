# %%
import pandas as pd

# %% [markdown]
# <h1>Working With Json</h1>

# %%
pd.read_json('train.json')
#isme bhi csv files jaise hi parameters pass krk exclusive values jinki need hai extract kar skte hain
#for details refer documentations
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://microsoftedge.github.io/Demos/json-dummy-data/1MB.json')
# Out:
#                 name language                id  \
# 0      Adeel Solangi   Sindhi  V59OF92YF627HFY0
# 1      Afzal Ghaffar   Sindhi  ENTOCR13RSCLZ6KU
# 2      Aamir Solangi   Sindhi  IAKPO3R4761JDRVG
# 3      Abla Dilmurat   Uyghur  5ZVOEPMJUI4MB4EN
# 4           Adil Eli   Uyghur  6VTI8X6LL0MMPJCC
# ...              ...      ...               ...
# 3163   Bhupesh Menon    Hindi  0CEPNRDV98KT3ORP
# 3164    Rohini Vasav    Hindi  UEFML43TCGS04KWM
# 3165    Sunil Kapoor    Hindi  VY2A0APGVHK5NAW2
# 3166  Zamokuhle Zulu  isiZulu  XU7BX2F8M5PVZ1EF
# 3167   Bhupesh Menon    Hindi  0CEPNRDV98KT3ORP
#
#                                                     bio  version
# 0     Donec lobortis eleifend condimentum. Cras dict...     6.10
# 1     Aliquam sollicitudin ante ligula, eget malesua...     1.88
# 2     Vestibulum pharetra libero et velit gravida eu...     7.27
# 3     Donec lobortis eleifend condimentum. Morbi ac ...     2.53
# ...

# %% [markdown]
# <h1>Working with SQL</h1>

# %%
# !pip install mysql.connector
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\PRABHAV\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\PRABHAV\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\PRABHAV\anaconda3\Lib\site-packages)

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df = pd.read_sql_query("SELECT * FROM city",conn)
# for more details go to documentations and read it
# Out:
# C:\Users\PRABHAV\AppData\Local\Temp\ipykernel_11980\3653681956.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM city",conn)

# %%
df
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %%
# Out:
#   Cell In[25], line 1
#     git status
#         ^
# SyntaxError: invalid syntax
