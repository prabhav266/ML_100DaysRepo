# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input2 = np.array([7,'male',38.0,1,1,23.5,'Q'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# C:\Users\PRABHAV\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\PRABHAV\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
