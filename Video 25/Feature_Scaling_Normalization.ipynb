# %% [markdown]
# <h2>MinMaxScaling</h2>

# %%
import pandas as pd#data processing
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np #linear lagebra

# %%
df = pd.read_csv('wine_data.csv',header = None,usecols=[0,1,2])
df.columns=['Class label','Alcohol','Malic Acid']

# %%
df
# Out:
#      Class label  Alcohol  Malic Acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(x=df.Alcohol)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(df['Malic Acid'])
# Out:
# <Axes: xlabel='Malic Acid', ylabel='Density'>

# %%
color_dict = {1:'red',2:'blue',3:'green'}
sns.scatterplot(x=df.Alcohol,y=df['Malic Acid'],hue=df['Class label'],palette= color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic Acid'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop('Class label', axis=1),
                                                df['Class label'],
                                                test_size=0.3,
                                                random_state=0)
X_train.shape,X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

#fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_train.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#        Alcohol  Malic Acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#        Alcohol  Malic Acid
# count    124.0       124.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.0         0.0
# 25%        0.4         0.2
# 50%        0.5         0.2
# 75%        0.7         0.5
# max        1.0         1.0

# %%
fig,(ax1,ax2)= plt.subplots(ncols=2,figsize=(12,5))
ax1.scatter(X_train['Alcohol'],X_train['Malic Acid'],c=y_train)
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scaled['Alcohol'],X_train_scaled['Malic Acid'],c=y_train)
ax2.set_title('After Scaling')
plt.show()

# %%
fig,(ax1,ax2)= plt.subplots(ncols=2,figsize=(12,5))

#before scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'],ax=ax1)
sns.kdeplot(X_train['Malic Acid'],ax=ax1)

#after scaling
ax2.set_title('After Scaling')
sns.kdeplot(X_train_scaled['Alcohol'],ax=ax2)
sns.kdeplot(X_train_scaled['Malic Acid'],ax=ax2)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter=1000)
lr_scaled = LogisticRegression(max_iter=1000)

# %%
lr.fit(X_train,y_train)
lr_scaled.fit(X_train_scaled,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = lr.predict(X_test)
y_pred_scaled = lr_scaled.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.7592592592592593
# Scaled 0.7962962962962963

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()
dt_scaled = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
dt_scaled.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)
y_pred_scaled = dt_scaled = dt_scaled.predict(X_test_scaled)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))
# Out:
# Actual 0.7777777777777778
# Scaled 0.7777777777777778

# %% [markdown]
# <h2>Mean Normalization</h2>

# %% [markdown]
# Xi' = (Xi - Xmean)/(Xmax - Xmin)
# **un algos mein use hota haijismein cenytered data chaiye ho**

# %% [markdown]
# **MaxAbsScaling**

# %% [markdown]
# **Xi' = Xi/|Xmax|**
# Has A class in sklearn named MaxAbsScale
# Useful When there is a sparse data

# %% [markdown]
# <h1>Robust Scaling</h1>

# %% [markdown]
# Xi' = (Xi-Xmedian)/IQR(75th Percentile Value-25thPercentile Value)
# sklearn mein RobustScaler krk ek classs hai usse use kr skte isko
#
# **IT IS ROBUST TO OUTLIERS**
